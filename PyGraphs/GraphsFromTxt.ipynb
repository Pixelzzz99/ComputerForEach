# %%
file = open('InformationFirstVersion.txt', 'r')
roster1 = [line.strip() for line in file]

# %%
len(roster1)
# Out:
# 100

# %%
file.close()
file = open('InformationSecondVersion.txt', 'r')
roster2 = [line.strip() for line in file]

# %%
len(roster2)
# Out:
# 100

# %%
time1 = 5
time2 = 2

# %%
import matplotlib.pyplot as ply 
from mpl_toolkits.mplot3d import Axes3D

# %%
x = len(roster1)
y = len(roster2)
z = time1;
fig = ply.figure()

ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, label='time1')
